# %% [markdown]
# 보험 분야에서 컴퓨터 비전이 활용될 수 있는데 보험에 들기 전 고객이 가입한 건물에 대해 조사를 할 경우에 쓰일 수 있습니다.
# 금융 분야의 또 다른 컴퓨터 비전 적용의 예로 은행의 신원 확인 절차를 자동화할 수 있습니다. 증권 쪽에선 컴퓨터 비전이 캔들스틱 차트의 새로운 패턴을 찾는 기술적 분석으로 쓰일 수 있습니다.
#
# 이번 챕터에서 다루는 토픽
# 1. Convolutional layers
# 2. Padding
# 3. Pooling
# 4. Regularization to prevent overfitting
# 5. Momentum-based optimization
# 6. Batch normalization
# 7. Advanced architectures for computer vision beyond classfication
# 8. A note on libraries

# %% [markdown]
# ## Convolution Neural Networks
# Convolution Neural Networks 또는 ConvNets, CNN이라고 불리는데 컴퓨터 비전을 작동시키는 엔진입니다. ConvNets은 사이즈가 큰 이미지를 합리적인 신경망의 사이즈를 유지하면서 다룰 수 있게 해줍니다.
#
# Convolution Neural Networks의 이름은 수학적 동작 원리에서 왔는데 일반적인 신경망과의 차이점에서 볼 수 있습니다. Convolution은 수학적인 용어인데 행렬에서 다른 행렬을 슬라이딩하는 것을 말합니다.
#
# ConvNets을 만들어 MNIST 데이터를 분류 해보겠습니다.

# %%
from keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# 데이터 셋은 6만여개의 28*28 픽셀의 이미지를 포함하고 있다. mnist 데이터는 black and white로 구성되어 있다.

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
# one-color 채널을 추가
import numpy as np
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
x_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
from keras.layers import Conv2D
from keras.models import Sequential

# %%
model = Sequential()
img_shape = (28, 28, 1)
model.add(Conv2D( filters = 6,
                  kernel_size = 3,
                  strides = 1,
                  padding = 'valid',
                  input_shape = img_shape))

# %% [markdown]
# ### Kernel size
# filter의 사이즈를 kernel_size라고도 부릅니다. 숫자 하나만 지정할 경우 keras에서 스퀘어로 인식합니다. 위 예에서 3을 넣었는데 3*3으로 인식합니다. (3, 4)를 입력으로 주면 3*4를 커널 사이즈로 인식합니다.
#
# ### Stride size
# Stride size는 컨볼루션 필터가 이미지 밖으로 얼마나 나갈지 정합니다. 커널 사이즈와 마찬가지로 값 하나만 설정할 경우 수직과 수평의 stride size를 같은 값으로 설정합니다. 그러나 (1, 2)와 같이 입력을 주어 설정할 수도 있습니다.
#
# ### Padding
# padding은 zero를 이미지 주변에 감싸는 것입니다.
#
# ### ReLU activation
# 합성곱 신경망은 선형 스텝만 수행합니다. 필터와 이미지를 곱하는 것은 선형 작업입니다.
# complex function을 approximate하기 위해선 비선형 활성화 함수가 필요합니다. 컴퓨터 비전에서 가장 가주사용하는 활성화 함수로 Rectified Linear Units, ReLU가 있습니다.
#
# $ReLU(x) = max(x, 0)$
#
# 렐루 함수는 음수의 모든 값을 0으로 바꾸기 때문에 계산량이 다른 활성화 함수보다 적습니다. gradient 즉 기울기가 매우 크고 음의 방향으로 가중치가 곱해질 때 ReLU의 미분은 항상 0입니다. 그래서 가중치가 절대 업데이트되지 않습니다. 이것은 뉴런이 활성화되지 않을 수 있다는 것을 의미하는데 learning rate를 작게함으로써 완화시킬 수 있습니다.
#
# 렐루 함수는 빠르고 계산량이 저렴하기 때문에 많은 실무자들의 디폴트 활성화 함수입니다.
#
# 케라스에서 렐루 함수를 쓰는 방법입니다.

# %%
from keras.layers import Activation
model.add(Activation('relu'))

# %% [markdown]
# ### MaxPooling2D
# convolutional layer 다음에 pooling layer를 두는 것은 흔한 관행입니다. Pooling은 feature map의 spatial size를 감소시키는데, 파라미터의 개수를 감소시키는 것으로 볼 수 있고 오버피팅을 방지합니다.
#
# 맥스 풀링은 플에서 가장 큰 값을 반환합니다. AveragePooling2D는 풀의 평균값을 반환합니다. 맥스풀링은 평균풀링보다 우수한 성능을 종종 주기 때문에 표준으로 쓰입니다.

# %%
from keras.layers import MaxPool2D
model.add(MaxPool2D(pool_size = 2, strides = None , padding='valid'))

# %% [markdown]
# ### Flatten
# 우리의 feature map은 3차원이지만 10개의 클래스에 대한 확률을 가진 1차원의 벡터를 원합니다. 어떻게 3D를 1D로 바꿀까요? Flatten이 바꿉니다.
# 넘파이의 Flatten과 비슷하게 작동합니다. (batch_size, height, width, channels)를 취하고 (batch_size, height * width * channels)를 반환합니다.
#
# 계산없이 행렬을 reshape할 뿐입니다. 그래서 하이퍼파라미터가 없습니다.

# %%
from keras.layers import Flatten
model.add(Flatten())

# %% [markdown]
# ### Dense
#
# ConvNet은 보통 feature extraction part, convolutional layers, classification part로 구성되어 있습니다. plain layer와 모든 다른 타입의 layer를 구별하기 위해 우리는 Dense 레이어라고 그들을 부릅니다. 덴스 레이러는 각 입력 뉴런은 출력 뉴런과 연결되어 있습니다. 우리는 10개의 숫자로 아웃풋을 특정화해야 합니다.
#
# 아래의 코드로 합니다.

# %%
from keras.layers import Dense
model.add(Dense(10))

# %% [markdown]
# 덴스 레이어 후에 멀티 클래스 회귀를 위해 softmax 활성화 함수를 추가합니다.

# %%
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 6)         60
# _________________________________________________________________
# activation (Activation)      (None, 26, 26, 6)         0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 6)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1014)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                10150
# _________________________________________________________________
# activation_1 (Activation)    (None, 10)                0
# =================================================================
# Total params: 10,210
# Trainable params: 10,210
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
y_train.shape
# Out:
# (60000,)

# %% [markdown]
# 타켓을 원 핫 인코딩 형식으로 변형 시켜 손실 함수를 계산하기 위해 sparse_categorical_crossentropy 손실 함수를 제공합니다.
# 크로스 엔트로피 손실 함수와 같은데 sparse에 쓰인다는 점이 다릅니다.

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer = 'adam', metrics=['acc'])

# %%
history = model.fit(x_train,
                    y_train,
                    batch_size=32,
                    epochs=10,
                    validation_data=(x_test,y_test))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 1.8673 - acc: 0.8959 - val_loss: 0.3461 - val_acc: 0.9466
# Epoch 2/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2225 - acc: 0.9535 - val_loss: 0.1718 - val_acc: 0.9561
# Epoch 3/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1231 - acc: 0.9658 - val_loss: 0.1298 - val_acc: 0.9608
# Epoch 4/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1004 - acc: 0.9706 - val_loss: 0.1239 - val_acc: 0.9641
# Epoch 5/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0920 - acc: 0.9720 - val_loss: 0.1078 - val_acc: 0.9676
# Epoch 6/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0814 - acc: 0.9748 - val_loss: 0.1097 - val_acc: 0.9662
# Epoch 7/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0783 - acc: 0.9761 - val_loss: 0.1166 - val_acc: 0.9683
# Epoch 8/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0692 - acc: 0.9786 - val_loss: 0.1213 - val_acc: 0.9694
# Epoch 9/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0656 - acc: 0.9799 - val_loss: 0.1185 - val_acc: 0.9692
# Epoch 10/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0615 - acc: 0.9808 - val_loss: 0.1141 - val_acc: 0.9715

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,6))
gen = ax.plot(history.history['val_acc'], label='Validation Accuracy')
fr = ax.plot(history.history['acc'],dashes=[5, 2], label='Training Accuracy')

legend = ax.legend(loc='lower center', shadow=True)

plt.show()

# %%
history.history
# Out:
# {'loss': [1.8673193454742432,
#   0.2225496470928192,
#   0.1231493353843689,
#   0.10039357095956802,
#   0.09203344583511353,
#   0.08135443180799484,
#   0.0783209502696991,
#   0.0691954642534256,
#   0.06558876484632492,
#   0.06149695813655853],
#  'acc': [0.8958500027656555,
#   0.953499972820282,
#   0.9658499956130981,
#   0.9706000089645386,
#   0.9720333218574524,
#   0.9748166799545288,
#   0.9760500192642212,
#   0.9786166548728943,
#   0.9799166917800903,
#   0.980816662311554],
#  'val_loss': [0.3461293578147888,
#   0.171758234500885,
#   0.12976320087909698,
#   0.12389368563890457,
#   0.1078491359949112,
#   0.10967761278152466,
#   0.11664450913667679,
#   0.12127645313739777,
#   0.11845466494560242,
#   0.11407841742038727],
#  'val_acc': [0.9466000199317932,
#   0.9560999870300293,
#   0.9607999920845032,
#   0.9641000032424927,
#   0.9675999879837036,
#   0.9661999940872192,
#   0.9682999849319458,
#   0.9693999886512756,
#   0.9692000150680542,
#   0.9714999794960022]}

# %% [markdown]
# ### Momentum
#
# 모델 파라미터를 곧바로 업데이트 시키기 보다는 이동 평균의 가중치를 이용해서 업데이트 하는 것 이상치로 보이는 gradient에 대해서 moving average를 취하면 이상치를 부드럽게 만들고 경사의 general한 방향을 capture할 수 있다.
#
# $V_t = \beta * V_{t-1} + (1-\beta) * \theta_t$
#
# $\theta_t$는 새로운 값을 의미하고 베타는 이전의 이동 평균에서 얼마를 가져올지를 의미한다.
#
# 모멘텀을 사용하면 robust하게 학습할 수 있다. 아래의 코드로 모멘텀을 설정할 수 있다.

# %%
from keras.optimizers import SGD
momentum_optimizer = SGD(lr= 0.01, momentum=0.9)

# %%
model.compile(optimizer = momentum_optimizer, loss = 'sparse_categorical_crossentropy', metrics=['acc'])

# %% [markdown]
# ### The Adam optimizer
#
# Adaptive Momentum Estimation는 경사 하강 잡을 효율적으로 할 수 있도록 도와준다. adam 옵티마이저는 모멘텀 옵티마이저가 했던 것 처럼 gradient의 지수가중이동평균을 계산한다. 아래의 formula로 계산한다.
#
# $V_{dW} = \beta_1 * V_{dW} + (1 - \beta_1) * dW$
#
# 그리고 squared gradient의 지수가중이동평균을 계산한다.
#
# $S_{dW} = \beta_2 * S_{dW} + (1 - \beta_2) * dW^2$
#
# 그리고 아래와 같이 모델 파라미터를 업데이트 한다.
#
# $W = W - \alpha * {V_{dW} \over \sqrt{S_{dW}} + \epsilon} $
#
# 여기서 epsilons는 division by zero를 피하기 위한 아주 작은 숫자이다.
#
# 경사(기울기)가 매우 클 때 업데이트 속도를 줄여주고 outlier에 대한 학습을 안정화 시킨다.
#
# 아담에서는 모멘텀 팩터 베타 하나만 가진 것에 반해 베타1과 베타2라는 하이퍼파라미터를 가진다. 각각 0.9와 0.999를 추천한다.
#
# 케라스에선 아래와 같이 사용한다.

# %%
from keras.optimizers import Adam
adam_optimizer = Adam(lr = 0.1, beta_1 = 0.9, beta_2 = 0.999, epsilon=1e-08)

# %%
model.compile(optimizer = adam_optimizer, loss = 'sparse_categorical_crossentropy', metrics=['acc'])

# %% [markdown]
# ### Regularization
#
# Regularization은 오버피팅을 피하기 위한 기술이다. 오버피팅은 훈련 데이터에 너무 잘 맞는 것을 말한다. 상용이나 테스트 데이터에선 잘 맞지 않는다. 오버피팅은 high variance라고 언급되며 언더피팅은 high bias라고 언급된다.
#
# 클래식한 통계 학습에선 bias-variance 트레이트 오프에 집중을 많이한다. 신경망에서 Regularization은 고전적인 통계 학습에서 많이 차용한다. 그러나 현대 기계 학습 연구는 다른 하이퍼 파라미터가 bias과 variance에 영향을 미친다는 개념인 "직교성(orthogonality)"의 개념을 수용하기 시작하고 있다.
#
# 이 hyperparameter를 분리함으로써 bias-variance 트레이드 오프를 깨부실 수 있으며 generalize well 하고 정확한 예측을 하는 모델을 찾을 수 있다. 그러나 이러한 편향과 분산이 작은 모델을 만들기 위한 방법은 많은 양의 훈련 데이터가 필요하기 때문에 쉽지 않다.

# %% [markdown]
# ### L2 regularization
#
# overfitting에 대응하기 위한 인기있는 기술은 L2 regularization이다. L2 regularization은 loss function에 제곱 가중치 합을 추가한다. 아래의 formula에서 예를 확인할 수 있다.
#
# $L_regularized(W) = L(W) + {\lambda \over 2N}\sum {W^2} $
#
# N은 테레이닝 example의 수이고 lambda는 regularization hyperparameter인데, 얼마나 regularization할지 정하는 것을 의미한다. 보통 0.01로 설정한다. L2 regularization을 loss function에 추가하면 높은 가중치는 loss를 증가시키고 알고리즘이 가중치를 줄인다. 가중치가 0정도로 작으면 덜 의존한다는 것을 의미한다.
#
# regularization 알고리즘은 단일 feature와 모든 single node activation에 덜 의존하며 전체적인 관점에서 feature와 activation을 고려한다. 오버피팅을 막는 알고리즘이다.
#
# ### L1 regularization
#
# L2 regularization과 굉장이 유사하다. sum of square를 추가하는 대신 sum of 절대값을 추가한다.
#
# $L_regularized(W) = L(W) + {\lambda \over 2N}\sum {||W||} $

# %% [markdown]
# ### Regularization in Keras
#
# Keras에서 가중치에 적용되는 regularizer를 kernel_regularizer라고 부른다. bias에 적용하는 것은 bias_regularizer라고 부른다. 그리고 Regularization을 노드들의 활성화에 적용할 수 있는데(활성화가 강하게 되는 것을 막기 위해) activity_regularizer라고 한다.
#
# L2 Regularization을 신경망에 적용해보자.

# %%
from keras.regularizers import l2

model = Sequential()

model.add(Conv2D(6,3,input_shape=img_shape, kernel_regularizer=l2(0.01)))
model.add(Activation('relu'))

model.add(MaxPool2D(2))

model.add(Conv2D(12,3,activity_regularizer=l2(0.01)))

model.add(Activation('relu'))

model.add(MaxPool2D(2))

model.add(Flatten())

model.add(Dense(10,bias_regularizer=l2(0.01)))

model.add(Activation('softmax'))

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer = 'adam', metrics=['acc'])

# %%
history = model.fit(x_train,
                    y_train,
                    batch_size=32,
                    epochs=10,
                    validation_data=(x_test,y_test))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 376.2075 - acc: 0.6754 - val_loss: 2.8582 - val_acc: 0.7999
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.6952 - acc: 0.8383 - val_loss: 1.1901 - val_acc: 0.8792
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.9839 - acc: 0.8891 - val_loss: 0.8012 - val_acc: 0.9174
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.7146 - acc: 0.9104 - val_loss: 0.5980 - val_acc: 0.9287
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5882 - acc: 0.9203 - val_loss: 0.5506 - val_acc: 0.9219
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5122 - acc: 0.9259 - val_loss: 0.4795 - val_acc: 0.9333
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4639 - acc: 0.9276 - val_loss: 0.4392 - val_acc: 0.9330
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4240 - acc: 0.9297 - val_loss: 0.3778 - val_acc: 0.9341
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3763 - acc: 0.9367 - val_loss: 0.3778 - val_acc: 0.9382
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3391 - acc: 0.9403 - val_loss: 0.3184 - val_acc: 0.9459

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,6))
gen = ax.plot(history.history['val_acc'], label='Validation Accuracy')
fr = ax.plot(history.history['acc'],dashes=[5, 2], label='Training Accuracy')

legend = ax.legend(loc='lower center', shadow=True)

plt.show()

# %% [markdown]
# ### Dropout
#
# overfitting을 막는 간단한 방법인데 랜덤하게 신경망에서 노드를 제거함으로써 오버피팅을 막는다. dropout으로 각각의 노드들은 activation을 0으로 설정할 수 있는 작은 가능성을 가지고 있다. 이것은 L2, L1 정규화 처럼 학습할 때 하나의 노드에 강하게 의존할 수 없다.
#
# 케라스에서 dropout은 새로운 타입의 레이어이다. dropout을 원하는 activation뒤에 놓으면 된다.

# %%
from keras.layers import Dropout


model = Sequential()


model.add(Conv2D(6,3,input_shape=img_shape))
model.add(Activation('relu'))
model.add(MaxPool2D(2))

model.add(Dropout(0.2))

model.add(Conv2D(12,3))
model.add(Activation('relu'))
model.add(MaxPool2D(2))

model.add(Dropout(0.2))

model.add(Flatten())

model.add(Dense(10,bias_regularizer=l2(0.01)))

model.add(Activation('softmax'))

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer = 'adam', metrics=['acc'])

# %%
history = model.fit(x_train,
                    y_train,
                    batch_size=32,
                    epochs=10,
                    validation_data=(x_test,y_test))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 3.8200 - acc: 0.6732 - val_loss: 0.3023 - val_acc: 0.9126
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3901 - acc: 0.8782 - val_loss: 0.1754 - val_acc: 0.9478
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2678 - acc: 0.9158 - val_loss: 0.1318 - val_acc: 0.9611
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2051 - acc: 0.9358 - val_loss: 0.0969 - val_acc: 0.9703
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1709 - acc: 0.9470 - val_loss: 0.0860 - val_acc: 0.9717
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1558 - acc: 0.9513 - val_loss: 0.0723 - val_acc: 0.9779
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1451 - acc: 0.9541 - val_loss: 0.0710 - val_acc: 0.9771
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1392 - acc: 0.9567 - val_loss: 0.0688 - val_acc: 0.9788
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1286 - acc: 0.9595 - val_loss: 0.0682 - val_acc: 0.9781
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1211 - acc: 0.9620 - val_loss: 0.0573 - val_acc: 0.9820

# %% [markdown]
# ### Batchnorm
# Batch Normalization의 약자인 Batchnorm은 입력 데이터를 배치 방식으로 "정규화"하는 기술이다. 각 batchnorm은 데이터의 평균 및 표준 편차를 계산하고 평균이 0이고 표준 편차가 1 인 변환을 적용한다.
#
# 이것은 loss surface이 'round'해서 훈련이 더 쉬워진다. 다른 인풋 차수에 따른 다른 평균과 표준편차는 신경망 학습시 더 복잡한 것을 배워야 한다는 것을 의미한다.

# %%
from keras.layers import BatchNormalization


model = Sequential()


model.add(Conv2D(6,3,input_shape=img_shape))
model.add(Activation('relu'))
model.add(MaxPool2D(2))

model.add(BatchNormalization())

model.add(Conv2D(12,3))
model.add(Activation('relu'))
model.add(MaxPool2D(2))

model.add(BatchNormalization())

model.add(Flatten())

model.add(Dense(10,bias_regularizer=l2(0.01)))

model.add(Activation('softmax'))

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer = 'adam', metrics=['acc'])

# %%
history = model.fit(x_train,
                    y_train,
                    batch_size=32,
                    epochs=10,
                    validation_data=(x_test,y_test))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2074 - acc: 0.9380 - val_loss: 0.0780 - val_acc: 0.9747
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0711 - acc: 0.9780 - val_loss: 0.0698 - val_acc: 0.9765
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0560 - acc: 0.9823 - val_loss: 0.0690 - val_acc: 0.9780
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0475 - acc: 0.9854 - val_loss: 0.0514 - val_acc: 0.9840
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0424 - acc: 0.9864 - val_loss: 0.0509 - val_acc: 0.9841
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0388 - acc: 0.9878 - val_loss: 0.0494 - val_acc: 0.9842
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0359 - acc: 0.9885 - val_loss: 0.0530 - val_acc: 0.9834
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0340 - acc: 0.9892 - val_loss: 0.0452 - val_acc: 0.9856
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0317 - acc: 0.9897 - val_loss: 0.0509 - val_acc: 0.9838
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0300 - acc: 0.9908 - val_loss: 0.0481 - val_acc: 0.9862

# %% [markdown]
# Batchnorm은 약간 regularizing 효과도 가지고 있다. *(extreme values)극단값은 종종 오버피팅 되는데 Batchnorm이 극단값을 줄여준다.

# %% [markdown]
# ### Working with big image datasets
#
# 이미지는 큰 파일인 경향이 있어 실제로 이미지 데이터 세트를 검퓨터의 RAM에 적합시킬 수 없을 가능성이 높다.
#
# 그러므로 이미지를 미리 한꺼번에 로드하기 보다는 즉시 로드하는게 필요하다.
#
# 데이터셋 링크: https://arxiv.org/abs/1711.05458
#
# finance를 다루는데 왜 식물 데이터를 다루는지에 대해 의문을 제기할 수 있는데 컴퓨터 비전의 여러 기술을 적용할 수 있어 선택했다.

# %%
import os
from tqdm import tqdm

root_dir = 'train'
target_root = 'validation'

if not os.path.isdir(target_root):
  os.mkdir(target_root)

for plant in tqdm(os.listdir(root_dir)):
  plant_path = os.path.join(root_dir,plant)
  target_plant_path = os.path.join(target_root,plant)
  
  if not os.path.isdir(target_plant_path):
    os.mkdir(target_plant_path)
    
    
  files = os.listdir(plant_path)
  for i in range(12):
    source_path = os.path.join(plant_path,files[i])
    dest_path = os.path.join(target_plant_path,files[i])
    os.rename(source_path,dest_path)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 139.91it/s]

# %%
import datetime
import numpy as np
from keras.preprocessing.image import ImageDataGenerator

# %%
import seaborn as sns
sns.set(); np.random.seed(0)
# %matplotlib inline

# %%
from tqdm import tqdm

# %%
import os
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
import cv2

# %%
imgen = ImageDataGenerator(rescale=1/255)

# %%
train_generator = imgen.flow_from_directory('train',batch_size=32, target_size=(150,150))
# Out:
# Found 4606 images belonging to 12 classes.

# %%
validation_generator = imgen.flow_from_directory('validation',
                                                 batch_size=32, 
                                                 target_size=(150,150))
# Out:
# Found 144 images belonging to 12 classes.

# %%
from keras.layers import Flatten, Dense, Activation
from keras.models import Sequential

# %%
model = Sequential()
model.add(Flatten(input_shape = (150,150,3)))
model.add(Dense(12))
model.add(Activation('softmax'))

# %%
model.compile(loss='categorical_crossentropy',optimizer='sgd', metrics = ['acc'])

# %%
model.fit_generator(train_generator,
                    epochs=10,
                    steps_per_epoch= 4606 // 32, 
                    validation_data=validation_generator, 
                    validation_steps= 144/32)
# Out:
# Epoch 1/10
# 143/143 [==============================] - 34s 237ms/step - loss: 17.5832 - acc: 0.1152 - val_loss: 6.9403 - val_acc: 0.0903
# Epoch 2/10
# 143/143 [==============================] - 33s 232ms/step - loss: 13.7278 - acc: 0.1434 - val_loss: 11.7836 - val_acc: 0.1319
# Epoch 3/10
# 143/143 [==============================] - 33s 234ms/step - loss: 11.4161 - acc: 0.1710 - val_loss: 10.2928 - val_acc: 0.2083
# Epoch 4/10
# 143/143 [==============================] - 34s 235ms/step - loss: 9.2375 - acc: 0.2075 - val_loss: 12.0185 - val_acc: 0.1319
# Epoch 5/10
# 143/143 [==============================] - 34s 235ms/step - loss: 9.3170 - acc: 0.2208 - val_loss: 10.6643 - val_acc: 0.1597
# Epoch 6/10
# 143/143 [==============================] - 33s 233ms/step - loss: 8.4534 - acc: 0.2339 - val_loss: 6.8069 - val_acc: 0.2500
# Epoch 7/10
# 143/143 [==============================] - 34s 239ms/step - loss: 8.0250 - acc: 0.2404 - val_loss: 12.0577 - val_acc: 0.1875
# Epoch 8/10
# 143/143 [==============================] - 34s 237ms/step - loss: 7.7190 - acc: 0.2763 - val_loss: 6.0422 - val_acc: 0.2778
# Epoch 9/10
# 143/143 [==============================] - 34s 236ms/step - loss: 6.4827 - acc: 0.2982 - val_loss: 8.7913 - val_acc: 0.2361
# Epoch 10/10
# 143/143 [==============================] - 33s 233ms/step - loss: 6.5239 - acc: 0.2978 - val_loss: 13.8410 - val_acc: 0.1597

# %% [markdown]
# ### Working with pretrained models
#
# large 컴퓨터 비전 모델을 학습시키는 것은 어려울 뿐만 아니라 계산적으로도 비쌉니다. 그러므로 원래 다른 목적으로 훈련된 모델을 사용하고 새로운 목적으로 미세 조정하는 것이 일반적이다. 이것은 전이 학습(transfer learning)의 한 예이다.
#
# transfer learning은 한 태스크에서 또다른 태스크로 학습을 전이 시키는 것을 말한다. 사람은 자신이 배운 것을 매우 잘 전이한다. 만일 처음 보는 개를 보더라도 이 새로운 개를 위해 모든 종류의 개를 학습할 필요는 없다. 새로 학습한 것을 이미 알고 있는 것에 넘겨줄(transfer) 뿐이다.
#
# 이번 섹션에선 원래 이미지넷 데이터셋으로 훈련된 VGG-16을 미세 조정한다. imageNet competition은 매년 열리는데 데이터셋은 현실의 물체에 대한 수백만의 이미지가 구성되어 있다. 개에서 부터 비행기까지..
#
# imageNet 경쟁에서 연구원들은 가장 정확한 모델을 만들기 위해 경쟁한다.사실, 이미지넷은 최근 몇 년 동안 컴퓨터 비전의 진보를 크게 이끌어왔고, 이미지넷 대회에서 만들어진 모델들은 모델을 fine-tune(미세 조정)하는 것이 인기있다.
#
# VGG-16은 옥스퍼드대학의 visual geometry group에 의해 만들어진 모델 구조이다. 모델은 convolutional part와 classification part로 구성되어 있다. 여기선 convolutional part만 쓰겠다. 거기에 우리만의 classification part를 더할 것이다.
#
# 아래 코드를 통해서 VGG-16은 다운 가능하다.

# %%
from keras.applications.vgg16 import VGG16
vgg_model = VGG16(include_top=False, input_shape=(150,150,3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 12s 0us/step

# %%
vgg_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# VGG 모델은 엄청 크고 14.7백만개의 학습가능한 파라미터가 존재한다. Conv2D와 MaxPooling2D 레이어로 구성되어 있다.
#
# 지금부터 우리가 진행할 두가지 방법이 있다.
#
# 1. 레이어를 추가해 새로운 모델을 만든다.
# 2. 모든 이미지를 전처리하여 새 모델을 학습한다.

# %% [markdown]
# ### Modifying VGG-16
#
# 이번 섹션에선 VGG-16 모델 위에 레이어를 추가하고 새로 훈련시키고자 한다.
#
# 우리는 이 모든 합성곱 신경망을 다시 훈련시키길 원치 않는다. 그래서 처음 VGG-16에 있는 모든 레이어를 freeze한다.

# %%
for layer in vgg_model.layers:
    layer.trainable = False

# %%
# funtional API를 통한 모델을 바꾸는 방법이다
finetune = Sequential(layers = vgg_model.layers)

# %% [markdown]
# 위 코드를 실행함으로써 finetune이라 불리는 새로운 모델을 만들었다. finetune은 보통의 sequential model이다. 기억해야할 사실이 있는데 sequential API로 모델을 바꾸는 것은 sequential API로 모델이 표현되어 있을때만 가능하다. 훨씬 복잡한 모델은 변환가능하지 않는다.

# %%
finetune.add(Flatten())
finetune.add(Dense(12))
finetune.add(Activation('softmax'))

# %%
finetune.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 12)                98316
# _________________________________________________________________
# activation_3 (Activation)    (None, 12)                0
# =================================================================
# Total params: 14,813,004
# Trainable params: 98,316
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
finetune.compile(loss='categorical_crossentropy',
                 optimizer='adam', 
                 metrics = ['acc'])

# %%
finetune.fit_generator(train_generator,
                    epochs=10,
                    steps_per_epoch= 5515 // 32, 
                    validation_data=validation_generator, 
                    validation_steps= 144//32)
# Out:
# Epoch 1/10
# 172/172 [==============================] - 43s 250ms/step - loss: 1.5893 - acc: 0.4780 - val_loss: 1.3997 - val_acc: 0.5781
# Epoch 2/10
# 172/172 [==============================] - 41s 237ms/step - loss: 0.9862 - acc: 0.6999 - val_loss: 1.3087 - val_acc: 0.5312
# Epoch 3/10
# 172/172 [==============================] - 41s 238ms/step - loss: 0.7485 - acc: 0.7854 - val_loss: 1.1613 - val_acc: 0.5938
# Epoch 4/10
# 172/172 [==============================] - 43s 248ms/step - loss: 0.6315 - acc: 0.8237 - val_loss: 1.0784 - val_acc: 0.6250
# Epoch 5/10
# 172/172 [==============================] - 40s 235ms/step - loss: 0.5447 - acc: 0.8517 - val_loss: 1.0199 - val_acc: 0.7109
# Epoch 6/10
# 172/172 [==============================] - 42s 246ms/step - loss: 0.4688 - acc: 0.8796 - val_loss: 1.0039 - val_acc: 0.6562
# Epoch 7/10
# 172/172 [==============================] - 41s 241ms/step - loss: 0.4194 - acc: 0.8937 - val_loss: 1.0903 - val_acc: 0.6172
# Epoch 8/10
# 172/172 [==============================] - 42s 243ms/step - loss: 0.3766 - acc: 0.9051 - val_loss: 1.0453 - val_acc: 0.6719
# Epoch 9/10
# 172/172 [==============================] - 41s 237ms/step - loss: 0.3409 - acc: 0.9213 - val_loss: 1.1211 - val_acc: 0.5859
# Epoch 10/10
# 172/172 [==============================] - 42s 242ms/step - loss: 0.3055 - acc: 0.9278 - val_loss: 0.9910 - val_acc: 0.6719

# %% [markdown]
# ### Random Augumentation
#
# 데이터를 아무리 많이 가지고 있어도 데이터를 더 많이 가지고 있는 것이 항상 더 좋다. 더 많으면 오버피팅을 막고 다양한 인풋에 대해서 모델이 동작할 수 있기 때문이다. 그래서 이미지에서 augmentation을 random하게 하는 것은 흔한 일이다.

# %%
train_datagen = ImageDataGenerator(
  rescale = 1/255,
  rotation_range=90,
  width_shift_range=0.2,
  height_shift_range=0.2,
  shear_range=0.2,
  zoom_range=0.1,
  horizontal_flip=True,
  fill_mode='nearest')

# %%
from keras.preprocessing import image
fname = 'train/Charlock/270209308.png'

# %%
img = image.load_img(fname, target_size=(150, 150))

# %%
img = image.img_to_array(img) # 이미지를 넘파이 어레이로 바꾼다.

# %%
print(img)
# Out:
# [[[ 69.  65.  63.]
#   [ 61.  56.  56.]
#   [ 67.  60.  62.]
#   ...
#   [ 87.  76.  75.]
#   [ 84.  75.  74.]
#   [ 83.  76.  73.]]
#
#  [[ 68.  64.  64.]
#   [ 68.  61.  63.]
#   [ 76.  70.  72.]
#   ...
#   [ 72.  59.  59.]
#   [ 70.  60.  59.]
#   [ 68.  59.  58.]]
#
#  [[ 91.  87.  88.]
#   [ 84.  80.  82.]
#   [ 83.  78.  80.]
#   ...
#   [ 66.  53.  54.]
#   [ 65.  55.  54.]
#   [ 72.  63.  60.]]
#
#  ...
#
#  [[114.  74.  51.]
#   [106.  68.  48.]
#   [101.  69.  52.]
#   ...
#   [ 54.  67.  37.]
#   [ 58.  71.  38.]
#   [ 58.  72.  39.]]
#
#  [[109.  74.  52.]
#   [100.  68.  48.]
#   [ 96.  66.  47.]
#   ...
#   [ 57.  69.  40.]
#   [ 57.  69.  37.]
#   [ 54.  67.  33.]]
#
#  [[100.  70.  46.]
#   [103.  75.  56.]
#   [ 98.  72.  55.]
#   ...
#   [ 57.  70.  41.]
#   [ 55.  68.  37.]
#   [ 54.  68.  35.]]]

# %%
img = np.expand_dims(img,axis=0) # 이미지 배치사이즈 차원을 더한다.

# %%
print(img)
# Out:
# [[[[ 69.  65.  63.]
#    [ 61.  56.  56.]
#    [ 67.  60.  62.]
#    ...
#    [ 87.  76.  75.]
#    [ 84.  75.  74.]
#    [ 83.  76.  73.]]
#
#   [[ 68.  64.  64.]
#    [ 68.  61.  63.]
#    [ 76.  70.  72.]
#    ...
#    [ 72.  59.  59.]
#    [ 70.  60.  59.]
#    [ 68.  59.  58.]]
#
#   [[ 91.  87.  88.]
#    [ 84.  80.  82.]
#    [ 83.  78.  80.]
#    ...
#    [ 66.  53.  54.]
#    [ 65.  55.  54.]
#    [ 72.  63.  60.]]
#
#   ...
#
#   [[114.  74.  51.]
#    [106.  68.  48.]
#    [101.  69.  52.]
#    ...
#    [ 54.  67.  37.]
#    [ 58.  71.  38.]
#    [ 58.  72.  39.]]
#
#   [[109.  74.  52.]
#    [100.  68.  48.]
#    [ 96.  66.  47.]
#    ...
#    [ 57.  69.  40.]
#    [ 57.  69.  37.]
#    [ 54.  67.  33.]]
#
#   [[100.  70.  46.]
#    [103.  75.  56.]
#    [ 98.  72.  55.]
#    ...
#    [ 57.  70.  41.]
#    [ 55.  68.  37.]
#    [ 54.  68.  35.]]]]

# %%
import matplotlib.pyplot as plt

gen = train_datagen.flow(img, batch_size=1)


for i in range(4):
    plt.figure(i)
    batch = next(gen)
    imgplot = plt.imshow(image.array_to_img(batch[0]))
    
plt.show()

# %% [markdown]
# ### modularity tradeoff
#
# ml에 적용할 수 있는 rule-based system에 대해 소개하고자 한다.
#
# 우선 end-to-end dl의 몇가지 결함을 알아본다.
# 1. 모델에 파라미터가 엄청 많기 때문에 엄청나게 많은 양의 데이터를 필요로 한다. 오버피팅을 막으려면..
# 2. e2eDL은 디버깅이 어렵다. 블랙 박스 모델의 전체 시스템을 바꾸자 한다면, 왜 그렇게 발생했는지 찾기가 매우 어렵다.
# 3. 코드로 짜기는 쉽지만 학습하기 어렵다. 특히 계산 결과가 참인지(Sanity check) 알기 어렵다.
#
# 최근에 연구자들은 그들의 모델을 더 모듈화 시키고 있다.
# 실질적인 입장에서 우리는 airbnb의 가격 엔진을 볼 수 있다.(https://medium.com/airbnb-engineering/learning-market-dynamics-for-optimal-pricing-97cffbcc53e3)
#
# 만약 가지고 있는 데이터가 작다면 사람의 통찰력이 들어갈 필요가 있다.
#
# 퓨어하게 엔드투엔드한 모델은 이미지 분야에선 드물다. 절대로 로우 데이터로 학습을 시키지 않는다.
# 스마트하게 태스크를 나누는 것이 성능을 올리고 리스크를 줄인다.

# %% [markdown]
# ### Computer vision beyond classification
#
# 위에서 보았들이 이미지 분류를 더 잘하기 위한 다양한 기술들이 있다.
#
# 마지막 섹션에서는 조금 더 창의적인 방법으로 이미지 분류를 잘하는 방법을 알아본다.
#
# 기술적 디테일을 몰라도 연구자들이 신경망을 창의적으로 사용했는지 보는데 집중한다.
#
# 이러한 것을 살펴보면서 우리가 앞으로 해결할 태스크에 비슷하게 적용할 수 있어 영감을 준다.

# %% [markdown]
# ### Facial recognition
#
# Facial recognition은 엄청 많이 존재한다.
#
# 수백만의 고객이 있지만 고객에 대한 사진은 한 두장 밖에 없다.
#
# 새로운 고객이 들어올 때 마다 모델을 업데이트 시킬 수 없다.
#
# 창의적 통찰은 여기에 적용되는데 고객의 얼굴을 분류하기 보다는 두 얼굴이 같은지 볼 수 있다.
#
# siamese network(샴 네트워크)는 두개 이상의 식별하는 네트워크가 있는데 둘 다 같은 가중치를 가지고 있다.
#
# 얼굴을 인식할 때마다 전체 샴 네트워크를 통해 데이터베이스에 있는 모든 고객 이미지를 실행하지 않으려면 샴 네트워크의 최종 출력을 정장하는 것이 일반적이다. 샴 네트워크의 최종 출력을 face embedding이라고 한다. 고객을 인식하고 싶을 때 데이터베이스에 저장된 고객 얼굴 이미지 임베딩을 비교한다. 우리는 이것을 단일 분류 레이어로 할 수 있다.
#
# facial embedding을 저장하는 것은 계산량을 줄이고, 얼굴을 군집화 하기 때문에 매우 이점이 있다. 얼굴은 성별 나이 인종에 따라 군집화 된다.
#
# 샴 네트워크를 훈련시키는 두가지 방법이 있는데 직접 face embedding을 생성하는 모델을 훈련하는 것이 더 좋다.(faceNet: A Unified Embedding for Face Recognition and Clustering)
#
# 이 아이디어를 세개의 이미지를 사용한다.
# 하나는 anchor 이미지 하나는 긍정 이미지 하나는 부정 이미지이다. anchor와 긍정의 거리는 작게 부정과는 크게 loss를 만든다.
#
# loss function은 아래와 같다.
# ![image.png](attachment:image.png)

# %% [markdown]
# YOLO(You Only Look Once)가 R-CNN(Region-based-CNN) 빠르다. R-CNN는 더 정확하다. 리얼타임을 원하면 YOLO 정확도를 원하면  R-CNN
